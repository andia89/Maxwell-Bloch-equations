# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import matplotlib.colors as colors
from matplotlib.colors import LogNorm
import h5py
from _create_pdf import create_spins, create_spins_inhomo_g
from _helper_functions import tsallis, cauchy, find_nearest, odeintz, find_nearest_sorted_left
from _steady_state import a_steady
from _mbes import mbes, mbes_soc
from _do_calculation import solve_mbes
#%qtconsole

# %%
gcoll = 31.174474083809773
q = 1.8048699796219885
quali =2786
fr = 3119.2;
kappa = np.pi*fr/quali #HWHM
delta = 0*2*np.pi #detuning cavity to spin central frequency ws-wc
deltac = 0*2*np.pi #detuning drive to cavity wc-wp
gperp = 2*np.pi*0.03 #HWHM
gpar = 2*np.pi*.0001#0.001 #HWHM
gammaq = 48.18060262895924
nbins = 1901#701#5000#20
g_number = 1 #how many bins for inhomogeneous coupling
#g0 = gcoll/sqrt(nspins)
print(kappa)
# Out:
# 3.5173208202000295

# %%
def g_inhomo_function(x, sigma):
    return np.exp(-x**2/sigma**2)

x_start = 5
x_stop = 20 #µm
x = np.linspace(x_start, x_stop, g_number)
sigma = 5
g_temp = g_inhomo_function(x, sigma)
g_list = g_temp/np.sum(g_temp)

# %%
spins, gs, pdf = create_spins_inhomo_g(gcoll, g_list, q, delta, gammaq, nbins, holes=False, inhomo=True, hyperfine=True)
plt.plot(spins[:len(pdf)], pdf/max(pdf))

# %%
initsteady = (0.001,0.001)
fstart = 50
deltaarr = np.linspace(-fstart*2*np.pi,fstart*2*np.pi, 2000)
etasteady = 0.00001
losasteady = np.zeros(np.shape(deltaarr))
losareal = np.zeros(np.shape(deltaarr))
losaimag = np.zeros(np.shape(deltaarr))

newinit = initsteady
for i, delt in enumerate(deltaarr):
    ar, ai = a_steady(etasteady, delt, gs, spins, gpar, gperp, kappa, newinit)
    newinit = (ar, ai)
    losasteady[i] = ai**2+ar**2
    losareal[i] = ar
    losaimag[i] = ai

fig = plt.figure()
plt.xlabel('$\Delta f$ (MHz)')
plt.ylabel('|A|² (dB)');
plt.plot(deltaarr/2/np.pi, 10*np.log10(losasteady/0.0000000001))
#deltaarr[find(losasteady == max(losasteady))]/2/pi

# %% [markdown]
# # SOC pulses

# %%
decaytime = 1220e-3
dt = 4e-3
tlistdecay = np.arange(0, decaytime+dt, dt)
scale = 0.1
init = np.ones(len(spins)*2+1)*(-1)
init[0] = 0
init[1::2] = 0

# %%
def pulse_rwa(t, args):
    wgrund = args[0]
    fcomps = args[1]
    pulse = 0
    for i in range(len(fcomps)):
        pulse = pulse+(fcomps[i])*np.sin((i+1)*wgrund*t)
    return pulse

tlist = np.arange(0, 0.504, dt)

fcomps = np.array([-1.177,  1.646, -0.549, -1.668, -0.627,  0.151,  1.68 , -0.024,
        0.858,  1.311, -0.15 , -0.355,  0.253,  1.165,  0.069,  0.47 ,
       -0.649, -0.814,  0.643, -0.657])
wgrund = 2*np.pi
nfreqs = int(len(fcomps)/2)

ilist = pulse_rwa(tlist, (wgrund, fcomps[:nfreqs]))
qlist = pulse_rwa(tlist, (wgrund, fcomps[nfreqs:]))

# %%
solpump, soldecay, infodict = solve_mbes(mbes_soc, init, pdf, tlist, tlistdecay, ilist, qlist, tlist, kappa, deltac, gs, gperp, spins, gpar)
a2pump = abs(solpump[:,0])**2
a2decay = abs(soldecay[:,0])**2
maxsim = max(max(a2pump), max(a2decay))

# %%
dataexp = scipy.io.loadmat('/mnt/samba2/experiments/Quantum InterConnect/Cryogenics/Dilution Fridge/LogFiles/SyncFolderAcqiris/Measurements/2016/20190124_MeasurementRun112/20190327_oct_maxampl1_finer/data.mat')

datidx = dataexp['data'][0].dtype.names.index('scan')
noiseidx = dataexp['data'][0].dtype.names.index('noisefloor')

datalin = dataexp['data'][0][0][datidx][0][30]
imeas = datalin[2]-np.mean(datalin[2][3500:4000])
qmeas = datalin[3]-np.mean(datalin[3][3500:4000])
a2exp = (imeas**2+qmeas**2)
texp = datalin[0]

noisefloor = dataexp['data'][0][0][noiseidx][0][0]
tnoise = np.squeeze(noisefloor[0])
inoise = np.squeeze(noisefloor[2]-np.mean(noisefloor[2][3500:4000]))
qnoise = np.squeeze(noisefloor[3]-np.mean(noisefloor[3][3500:4000]))
a2noise = inoise**2+qnoise**2

# %%
toff = 0.72
idxstart = 800
idx = 3900
plt.figure(figsize=(10,8))

a2all = (np.squeeze(imeas)-np.squeeze(inoise))**2+(np.squeeze(qmeas)-np.squeeze(qnoise))**2
#plt.plot(np.squeeze(texp)[idxstart:idx]*1e6-toff, a2exp[idxstart:idx]/max(a2exp))
#plt.plot(np.squeeze(texp)[idxstart:idx]*1e6-toff, a2all[idxstart:idx]/max(a2all[idxstart:idx]))
plt.plot(tlist, a2pump/maxsim, tlistdecay+tlist[-1], a2decay/maxsim)

plt.xlabel('Time (µs)')
plt.ylabel('$|\mathrm{A}|^2$');
# %qtconsole

# %% [markdown]
# ## Compare with data

# %%
datalin = dataexp['data'][0][0][datidx][0]
pin = np.arange(-30, 0.1, 0.5)
aref = 90

ain = aref*10**(pin/20)
texp2 = np.squeeze(datalin[0][0])[idxstart:idx]*1e6-toff
tsim = np.hstack((tlist, tlist[-1]+tlistdecay))

a2listsimpump = {}
a2listsimdecay = {}
a2listdat = {}
invlistsimpump = {}
invlistsimdecay = {}

for i, dat in enumerate(pin):
    if i<len(datalin):
        imeas = datalin[i][2]-np.mean(datalin[i][2][3500:4000])
        qmeas = datalin[i][3]-np.mean(datalin[i][3][3500:4000])
        a2exp = (np.squeeze(imeas)-np.squeeze(inoise))**2+(np.squeeze(qmeas)-np.squeeze(qnoise))**2
        expdat = np.squeeze(a2exp[idxstart:idx])
        a2listdat[dat] = expdat
    
    asolpump, asoldecay, infodict = solve_mbes(mbes_soc, init, pdf, tlist, tlistdecay, ilist*ain[i], qlist*ain[i],tlist, kappa, deltac, gs, gperp, spins, gpar)
    a2pump2 = asolpump[:,0]
    invpump = np.real(np.sum(asolpump[:,2::2], axis=1))
    invdecay= np.real(np.sum(asoldecay[:,2::2], axis=1))
    a2decay2 = asoldecay[:,0]
    
    a2listsimpump[dat] =  abs(a2pump2)**2
    a2listsimdecay[dat] = abs(a2decay2)**2
    invlistsimpump[dat] = invpump
    invlistsimdecay[dat] = invdecay


a2dat = []
a2sim = []
for i, dat in enumerate(pin):
    if dat in a2listdat.keys():
        a2dat.append(a2listdat[dat])

    a2pump2 = a2listsimpump[dat]
    a2decay2 = a2listsimdecay[dat]
    a2sim.append(np.hstack((a2pump2, a2decay2)))

tbef = np.arange(-0.32, 0, dt)
a2sim = np.asarray(a2sim)
a2empt = np.zeros((len(pin), len(tbef)))
a2dat = np.asarray(a2dat)

# %%
scalem = 2.4e-3
pdatlist = [-9]
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2,figsize=(16,16))
ax1.set_xlabel('Time (µs)')
ax2.set_xlabel('Time (µs)')
ax1.set_ylabel('|A|^2');
ax2.set_ylabel('Inversion');

for i, val in enumerate(pdatlist):
    print("Input Power: %d"%val)
    if val in a2listdat.keys():
        ax1.plot(texp2, a2listdat[val])
    ax1.plot(tlist, a2listsimpump[val]*scalem, tlistdecay+tlist[-1], a2listsimdecay[val]*scalem)
    ax2.plot(tlist, (1+invlistsimpump[val])/2, 'r', tlistdecay+tlist[-1], (1+invlistsimdecay[val])/2, 'k')

ax3.set_xlabel('Time (µs)')
ax3.set_ylabel('|A|^2');
ax4.set_xlabel('Time (µs)')
ax4.set_ylabel('|A|^2');

minclip = 0.00001
ax3.pcolormesh(texp2, sorted(list(a2listdat.keys())), a2dat, norm=LogNorm(vmin=minclip, vmax=a2dat.max()))
ax4.pcolormesh(np.hstack((tbef, tsim)), pin, np.clip(np.hstack((a2empt, a2sim)),minclip, None), norm=LogNorm(vmin=minclip, vmax=a2sim.max()))
# Out:
# Input Power: -9
# <ipython-input-37-7c4d943fbb8b>:22: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax3.pcolormesh(texp2, sorted(list(a2listdat.keys())), a2dat, norm=LogNorm(vmin=minclip, vmax=a2dat.max()))
# <ipython-input-37-7c4d943fbb8b>:23: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax4.pcolormesh(np.hstack((tbef, tsim)), pin, np.clip(np.hstack((a2empt, a2sim)),minclip, None), norm=LogNorm(vmin=minclip, vmax=a2sim.max()))

# %%
decaytimeup = 1500e-2
dtup = 8e-2
tlistdecayup = np.arange(0, decaytimeup+dtup, dtup)
initup = np.ones(nbins*2+1)*1
initup[0] = 0
initup[1::2] = 0
powerin = 1e-16
asolpumpup, asoldecayup, infodict = solve_mbes(mbes, initup, pdf, tlist, tlistdecayup, powerin, kappa, deltac, gs, gperp, spins, gpar)
a2pump2up = abs(asolpumpup[:,0])**2
invpumpup = np.real(np.sum(asolpumpup[:,2::2], axis=1))
invdecayup = np.real(np.sum(asoldecayup[:,2::2], axis=1))
a2decay2up = abs(asoldecayup[:,0])**2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-fc493147caf0> in <module>
#       6 initup[1::2] = 0
#       7 powerin = 1e-16
# ----> 8 asolpumpup, asoldecayup, infodict = solve_mbes(mbes, initup, pdf, tlist, tlistdecayup, powerin, kappa, deltac, gs, gperp, spins, gpar)
#       9 a2pump2up = abs(asolpumpup[:,0])**2
#      10 invpumpup = np.real(np.sum(asolpumpup[:,2::2], axis=1))
#
# ~/Dropbox/iPython-Notebooks/_do_calculation.ipynb in solve_mbes(mbes_func, init, pdf, tlistpump, tlistdecay, *args)
#      16    ],
#      17    "source": [
# ---> 18     "%matplotlib inline\n",
#      19     "import numpy as np\n",
#      20     "import nbimporter\n",
#
# ~/Dropbox/iPython-Notebooks/_helper_functions.ipynb in odeintz(func, z0, t, **kwargs)
#      20    "outputs": [],
#      21    "source": [
# ---> 22     "def tsallis(f, q, width):\n",
#      23     "    delta = (width)/2*np.sqrt(2*q-2)/np.sqrt(2**q-2)/np.sqrt(2)\n",
#      24     "    norm = np.sqrt(q-1)*gamma(1/(q-1))/(np.sqrt(2*np.pi)*delta*gamma((3-q)/(2*(q-1))))\n",
#
# /usr/local/lib/python3.8/dist-packages/scipy/integrate/odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     239     t = copy(t)
#     240     y0 = copy(y0)
# --> 241     output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     242                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     243                              ixpr, mxstep, mxhnil, mxordn, mxords,
#
# ~/Dropbox/iPython-Notebooks/_helper_functions.ipynb in realfunc(x, t, *args)
#      14    ]
#      15   },
# ---> 16   {
#      17    "cell_type": "code",
#      18    "execution_count": 2,
#
# ~/Dropbox/iPython-Notebooks/_mbes.ipynb in mbes(Y, t, eta, kappa, deltac, gs, gperp, spins, gpar)
#       5    "execution_count": 1,
#       6    "metadata": {},
# ----> 7    "outputs": [
#       8     {
#       9      "name": "stdout",
#
# KeyboardInterrupt:

# %%
fig, ((ax1, ax2)) = plt.subplots(1,2 ,figsize=(14,5))
ax1.set_xlabel('Time (µs)')
ax2.set_xlabel('Time (µs)')
ax1.set_ylabel('$|\mathrm A|^2$');
ax2.set_ylabel('Inversion');

ax1.plot(tlist, a2pump2up, tlistdecayup+tlist[-1], a2decay2up)
ax2.plot(tlist, invpumpup, tlistdecayup+tlist[-1], invdecayup)
# Out:
# [<matplotlib.lines.Line2D at 0x7f9302622fd0>,
#  <matplotlib.lines.Line2D at 0x7f930262f040>]
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f93729203a0> (for post_execute):
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2616         try:
# -> 2617             result = self._expression.parseString(s)
#    2618         except ParseBaseException as err:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1946                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1947                 raise exc
#    1948         else:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1936         try:
# -> 1937             loc, tokens = self._parse(instring, 0)
#    1938             if parseAll:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4051             else:
# -> 4052                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4053             if exprtokens or exprtokens.haskeys():
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4763         try:
# -> 4764             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4765         except (ParseException, IndexError):
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4679             try_not_ender(instring, loc)
# -> 4680         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4681         try:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4034         # pre-parsed the string as part of our And pre-parsing
# -> 4035         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4036         errorStop = False
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1709                     try:
# -> 1710                         tokens = fn(instring, tokensStart, retTokens)
#    1711                     except IndexError as parse_action_exc:
#
# /usr/lib/python3/dist-packages/pyparsing.py in wrapper(*args)
#    1315             try:
# -> 1316                 ret = func(*args[limit[0]:])
#    1317                 foundArity[0] = True
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in math_string(self, s, loc, toks)
#    2679     def math_string(self, s, loc, toks):
# -> 2680         return self._math_expression.parseString(toks[0][1:-1])
#    2681
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1946                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1947                 raise exc
#    1948         else:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1936         try:
# -> 1937             loc, tokens = self._parse(instring, 0)
#    1938             if parseAll:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4689                     preloc = loc
# -> 4690                 loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4691                 if tmptokens or tmptokens.haskeys():
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4236             try:
# -> 4237                 ret = e._parse(instring, loc, doActions)
#    4238                 return ret
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1709                     try:
# -> 1710                         tokens = fn(instring, tokensStart, retTokens)
#    1711                     except IndexError as parse_action_exc:
#
# /usr/lib/python3/dist-packages/pyparsing.py in wrapper(*args)
#    1315             try:
# -> 1316                 ret = func(*args[limit[0]:])
#    1317                 foundArity[0] = True
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in unknown_symbol(self, s, loc, toks)
#    2774         c = toks[0]
# -> 2775         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2776
#
# ParseFatalException: Unknown symbol: \mathrm, found '\'  (at char 1), (line:1, col:2)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in post_execute()
#     136             def post_execute():
#     137                 if matplotlib.is_interactive():
# --> 138                     draw_all()
#     139
#     140             # IPython >= 2
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     136         for manager in cls.get_all_fig_managers():
#     137             if force or manager.canvas.figure.stale:
# --> 138                 manager.canvas.draw_idle()
#     139
#     140
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2010         if not self._is_idle_drawing:
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#    2014     @cbook.deprecated("3.2")
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2746             renderer.stop_rasterizing()
#    2747
# -> 2748         mimage._draw_list_compositing_images(renderer, self, artists)
#    2749
#    2750         renderer.close_group('axes')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1176         self._update_label_position(renderer)
#    1177
# -> 1178         self.label.draw(renderer)
#    1179
#    1180         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/text.py in draw(self, renderer)
#     677
#     678         with _wrap_text(self) as textobj:
# --> 679             bbox, info, descent = textobj._get_layout(renderer)
#     680             trans = textobj.get_transform()
#     681
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     291             clean_line, ismath = self._preprocess_math(line)
#     292             if clean_line:
# --> 293                 w, h, d = renderer.get_text_width_height_descent(
#     294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     231         if ismath:
#     232             ox, oy, width, height, descent, fonts, used_characters = \
# --> 233                 self.mathtext_parser.parse(s, self.dpi, prop)
#     234             return width, height, descent
#     235
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in parse(self, s, dpi, prop)
#    3338         # mathtext.fontset rcParams also affect the parse (e.g. by affecting
#    3339         # the glyph metrics).
# -> 3340         return self._parse_cached(
#    3341             s, dpi, prop, rcParams['ps.useafm'], rcParams['mathtext.fontset'])
#    3342
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in _parse_cached(self, s, dpi, prop, ps_useafm, fontset)
#    3362             self.__class__._parser = Parser()
#    3363
# -> 3364         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3365         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3366         return font_output.get_results(box)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2617             result = self._expression.parseString(s)
#    2618         except ParseBaseException as err:
# -> 2619             raise ValueError("\n".join(["",
#    2620                                         err.line,
#    2621                                         " " * (err.column - 1) + "^",
#
# ValueError:
# |\mathrm A|^2
#  ^
# Unknown symbol: \mathrm, found '\'  (at char 1), (line:1, col:2)
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2616         try:
# -> 2617             result = self._expression.parseString(s)
#    2618         except ParseBaseException as err:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1946                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1947                 raise exc
#    1948         else:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1936         try:
# -> 1937             loc, tokens = self._parse(instring, 0)
#    1938             if parseAll:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4051             else:
# -> 4052                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4053             if exprtokens or exprtokens.haskeys():
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4763         try:
# -> 4764             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4765         except (ParseException, IndexError):
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4679             try_not_ender(instring, loc)
# -> 4680         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4681         try:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4034         # pre-parsed the string as part of our And pre-parsing
# -> 4035         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4036         errorStop = False
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1709                     try:
# -> 1710                         tokens = fn(instring, tokensStart, retTokens)
#    1711                     except IndexError as parse_action_exc:
#
# /usr/lib/python3/dist-packages/pyparsing.py in wrapper(*args)
#    1315             try:
# -> 1316                 ret = func(*args[limit[0]:])
#    1317                 foundArity[0] = True
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in math_string(self, s, loc, toks)
#    2679     def math_string(self, s, loc, toks):
# -> 2680         return self._math_expression.parseString(toks[0][1:-1])
#    2681
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1946                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1947                 raise exc
#    1948         else:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1936         try:
# -> 1937             loc, tokens = self._parse(instring, 0)
#    1938             if parseAll:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4689                     preloc = loc
# -> 4690                 loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4691                 if tmptokens or tmptokens.haskeys():
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# /usr/lib/python3/dist-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4236             try:
# -> 4237                 ret = e._parse(instring, loc, doActions)
#    4238                 return ret
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# /usr/lib/python3/dist-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1709                     try:
# -> 1710                         tokens = fn(instring, tokensStart, retTokens)
#    1711                     except IndexError as parse_action_exc:
#
# /usr/lib/python3/dist-packages/pyparsing.py in wrapper(*args)
#    1315             try:
# -> 1316                 ret = func(*args[limit[0]:])
#    1317                 foundArity[0] = True
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in unknown_symbol(self, s, loc, toks)
#    2774         c = toks[0]
# -> 2775         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2776
#
# ParseFatalException: Unknown symbol: \mathrm, found '\'  (at char 1), (line:1, col:2)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2746             renderer.stop_rasterizing()
#    2747
# -> 2748         mimage._draw_list_compositing_images(renderer, self, artists)
#    2749
#    2750         renderer.close_group('axes')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1176         self._update_label_position(renderer)
#    1177
# -> 1178         self.label.draw(renderer)
#    1179
#    1180         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/text.py in draw(self, renderer)
#     677
#     678         with _wrap_text(self) as textobj:
# --> 679             bbox, info, descent = textobj._get_layout(renderer)
#     680             trans = textobj.get_transform()
#     681
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     291             clean_line, ismath = self._preprocess_math(line)
#     292             if clean_line:
# --> 293                 w, h, d = renderer.get_text_width_height_descent(
#     294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     231         if ismath:
#     232             ox, oy, width, height, descent, fonts, used_characters = \
# --> 233                 self.mathtext_parser.parse(s, self.dpi, prop)
#     234             return width, height, descent
#     235
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in parse(self, s, dpi, prop)
#    3338         # mathtext.fontset rcParams also affect the parse (e.g. by affecting
#    3339         # the glyph metrics).
# -> 3340         return self._parse_cached(
#    3341             s, dpi, prop, rcParams['ps.useafm'], rcParams['mathtext.fontset'])
#    3342
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in _parse_cached(self, s, dpi, prop, ps_useafm, fontset)
#    3362             self.__class__._parser = Parser()
#    3363
# -> 3364         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3365         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3366         return font_output.get_results(box)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2617             result = self._expression.parseString(s)
#    2618         except ParseBaseException as err:
# -> 2619             raise ValueError("\n".join(["",
#    2620                                         err.line,
#    2621                                         " " * (err.column - 1) + "^",
#
# ValueError:
# |\mathrm A|^2
#  ^
# Unknown symbol: \mathrm, found '\'  (at char 1), (line:1, col:2)
