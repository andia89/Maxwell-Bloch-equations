# %%
# %matplotlib inline
import numpy as np
from scipy.stats import logistic
from scipy.optimize import basinhopping
from scipy import interpolate
from IPython.display import clear_output, Javascript, Markdown
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import scipy.io
import gc
import datetime
import time
import random
import matplotlib
import nbimporter
from _create_pdf import create_spins, create_spins_inhomo_g
from _helper_functions import tsallis, cauchy, find_nearest, odeintz, find_nearest_sorted_left
from _steady_state import a_steady
from _mbes import mbes, mbes_soc
from _do_calculation import solve_mbes_pump_probe, solve_mbes
#matplotlib.pyplot.switch_backend('nbAgg')
#%qtconsole
# Out:
# Importing Jupyter notebook from _create_pdf.ipynb
# Importing Jupyter notebook from _helper_functions.ipynb
# Importing Jupyter notebook from _steady_state.ipynb
# Importing Jupyter notebook from _mbes.ipynb
# Importing Jupyter notebook from _do_calculation.ipynb

# %%
gcoll = 45.18409188666773
q = 1.0058294512857613
quali = 1200
fr = 3092;
kappa = np.pi*fr/quali #HWHM
delta = 0*2*np.pi #detuning cavity to spin central frequency ws-wc
deltac = 0*2*np.pi #detuning drive to cavity wc-wp
gperp = 2*np.pi*0.09 #HWHM
gpar = 2*np.pi*.001#0.001 #HWHM
gammaq = 116.7755270154724
nbins = 1701#701#5000#20
g_number = 1 #how many bins for inhomogeneous coupling
#g0 = gcoll/sqrt(nspins)
print(kappa)
# Out:
# 8.0948370707497

# %%
def pulse_rwa(t, args):
    wgrund = args[0]
    fcomps = args[1]
    pulse = 0
    for i in range(len(fcomps)):
        pulse = pulse+(fcomps[i])*np.sin((i+1)*wgrund*t)
    return pulse

def pulse_rwa_gauss(t, args):
    wgrund = args[0]
    fcomps = args[1]
    nfcomps = len(fcomps)
    tend = np.pi/wgrund
    
    width = 2*tend/(nfcomps+5)
    t0 = 3*width/2
    pulse = 0
    for i in range(len(fcomps)):
        pulse += fcomps[i]*np.exp(-4*(t-t0)**2*np.log(2)/width**2)
        t0 += 0.5*width
    pulse *= logistic.cdf(t, loc=0.01, scale=.002)*(1-logistic.cdf(t, loc=tend-0.01, scale=.002))
    pulse *= 0.46971947398573455
    return pulse

def pulse_rwa_gauss_const(t, args):
    wgrund = args[0]
    fcomps = args[1]
    maxampl = args[2]
    nfcomps = len(fcomps)
    tend = np.pi/wgrund

    #xint = np.linspace(0, tend, nfcomps)
    
    #spline = interpolate.BSpline(xint, fcomps, 2)
    spline = 0
    for i in range(len(fcomps)):
        spline += (fcomps[i])*np.sin((i+1)*wgrund*t)

    #spline = spline/nfcomps
    pulsei = 0
    pulseq = 0
    pulse = 0
    pulse = maxampl*logistic.cdf(t, loc=0.02, scale=0.004)*(1-logistic.cdf(t, loc=tend-0.02, scale=0.004))
    
    pulsei = pulse*np.cos(spline)
    pulseq = pulse*np.sin(spline)

    return pulsei, pulseq

# %%
def g_inhomo_function(x, sigma):
    return np.exp(-x**2/sigma**2)

x_start = 5
x_stop = 20 #µm
x = np.linspace(x_start, x_stop, g_number)
sigma = 5
g_temp = g_inhomo_function(x, sigma)
g_list = g_temp/np.sum(g_temp)

# %%
spins, gs, pdf = create_spins_inhomo_g(gcoll, g_list, q, delta, gammaq, nbins, holes=False, inhomo=True, hyperfine=True)
plt.figure()
plt.plot(spins[:len(pdf)], pdf/max(pdf))
plt.xlabel('$\Delta f$ (MHz)')
plt.ylabel('weight');
#%qtconsole

# %%
initsteady = (0.1,0.1)
fstart = 50
deltaarr = np.linspace(-fstart*2*np.pi,fstart*2*np.pi, 2000)
etasteady = 0.00001
losasteady = np.zeros(np.shape(deltaarr))
losareal = np.zeros(np.shape(deltaarr))
losaimag = np.zeros(np.shape(deltaarr))

newinit = initsteady
for i, delt in enumerate(deltaarr):
    ar, ai = a_steady(etasteady, delt, gs, spins, gpar, gperp, kappa, newinit)
    newinit = (ar, ai)
    losasteady[i] = ai**2+ar**2
    losareal[i] = ar
    losaimag[i] = ai

fig = plt.figure()
plt.xlabel('$\Delta f$ (MHz)')
plt.ylabel('|A|² (dB)');
plt.plot(deltaarr/2/np.pi, 10*np.log10(losasteady/0.0000000001))
#deltaarr[find(losasteady == max(losasteady))]/2/pi

# %% [markdown]
# # SOC pulses

# %%
pumptime = 200e-3#5*np.pi/gcoll
decaytime = 500e-3
intertime = 10000e-3
probetime = 20e-3
dt = 4e-3 #The time resolution of the AWG. Don't change that because the solution of the MBEs are written in a way that use that as time resolution
numsteps = int(pumptime/dt)
tlist = np.arange(0,pumptime+dt,dt)
tlistdecay = np.arange(0, decaytime+dt, dt)

# test time it takes to calculate


init = np.ones(len(spins)*2+1)*(-1)
init[0] = 0
init[1::2] = 0

# %% [markdown]
# ### Calibrate power

# %%
pulsei = np.ones((len(tlist)))
pin = np.arange(-15, 0,0.5)
aref = 150

alos = np.zeros((len(pin), len(tlist)+len(tlistdecay)))
szlos = np.zeros(np.shape(alos))
szall = np.zeros((len(pin), len(tlist)+len(tlistdecay), nbins))
small = np.zeros(np.shape(szall))
smlos = np.zeros(np.shape(alos))

for ctr, p in enumerate(pin):
    dr = aref*10**(p/20.)
    asolpump, asoldecay, infodict = solve_mbes(mbes, init, pdf, tlist, tlistdecay, dr, kappa, deltac, gs, gperp, spins, gpar)
    alos[ctr, : ] = np.hstack((abs(asolpump[:,0])**2, abs(asoldecay[:,0])**2))
    szlos[ctr, :] = np.hstack((np.real(np.sum(asolpump[:, 2::2], axis=1)), np.real(np.sum(asoldecay[:, 2::2], axis=1))))
    szall[ctr, :, :] = np.vstack((np.real(asolpump[:,2::2]), np.real(asoldecay[:,2::2])))
    small[ctr, :, :] = np.vstack((np.real(asolpump[:,1::2]), np.real(asoldecay[:,1::2])))
    smlos[ctr, :] = np.hstack((np.real(np.sum(asolpump[:, 1::2], axis=1)), np.real(np.sum(asoldecay[:, 1::2], axis=1))))

# %%
tplot = np.linspace(0, 1000*(pumptime+decaytime), len(tlist)+len(tlistdecay))

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,5))

ax1.pcolor(tplot, pin, alos, vmin=0, vmax=60)
ax1.set_xlabel('Time (ns)')
ax1.set_ylabel('Input power (dB)');

ax2.pcolor(tplot, pin, szlos)
ax2.set_xlabel('Time (ns)')
ax2.set_ylabel('Input power (dB)');
# Out:
# <ipython-input-9-0993edfcf8c6>:5: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax1.pcolor(tplot, pin, alos, vmin=0, vmax=60)
# <ipython-input-9-0993edfcf8c6>:9: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax2.pcolor(tplot, pin, szlos)

# %% [markdown]
# ### Linear Rabi oscillations

# %%
alos = np.zeros((len(tlist)+len(tlistdecay)))
szlos = np.zeros(np.shape(alos))

asolpump, asoldecay, infodict = solve_mbes(mbes, init, pdf, tlist, tlistdecay, 0.00001, kappa, deltac, gs, gperp, spins, gpar)
alos = np.hstack((abs(asolpump[:,0])**2, abs(asoldecay[:,0])**2))
szlos = np.hstack((np.real(np.sum(asolpump[:, 2::2], axis=1)), np.real(np.sum(asoldecay[:, 2::2], axis=1))))
                  
                  
tplot = np.linspace(0, 1000*(pumptime+decaytime), len(tlist)+len(tlistdecay))

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,5))

ax1.plot(tplot, alos)
ax1.set_xlabel('Time (ns)')
ax1.set_ylabel('Cavity population');

ax2.plot(tplot, szlos)
ax2.set_xlabel('Time (ns)')
ax2.set_ylabel('Inversion');

# %%
number_fcp = 3
ttest = np.linspace(0,pumptime,numsteps)
wgrund = np.pi/ttest[-1]
sumsin = np.zeros((number_fcp, len(ttest)))

fig, ax = plt.subplots(1,1, figsize=(8,5))

for i in range(number_fcp):
    sumsin[i, :] = np.sin(wgrund*ttest*(i+1))
    ax.plot(ttest, sumsin[i,:])
ax.plot(ttest, np.sum(sumsin, axis=0))
maxfourier = max(np.sum(sumsin, axis=0))

# %%
class BasinHopping:
    
    def __init__(self):
        self.tp = np.arange(0,pumptime+dt,dt)
        self.td = np.arange(0, decaytime+dt, dt)
        self.ti = np.arange(0, intertime+dt, dt)
        self.tpr = np.arange(0, probetime+dt, dt)
        self.number_fcp = number_fcp
        self.pulse_length = 0.3
        self.min_pulse_length = 0.02
        self.max_ampl = aref/2
        self.max_t_ampl = aref
        self.target_time_decay = 1.9 #when after switching off the pulse the inversion should be maximum
        self.wgrund = np.pi/self.tp[-1]
        self.plot_handle = None
        self.max_time = .8 #maximum time pulse is allowed to last
        self.counter = 0
        self.solution = None
        self.fcomps = None
        self.idx = -1
        self.fitness = 0
        self.constant_on = True
        self.maxcav = 0
        self.ampl_probe = 1e-3
        self.vars = []
        self.fig = None
        self.disp1 = display(Markdown(""), display_id='0')
        self.best_fitness = 1.
        self.scale_factor = 2*np.pi if self.number_fcp == 0 else 2*np.pi/self.number_fcp
        

        
    def main(self, initial=None):
        self.counter = 0
        t = datetime.datetime.now()
        self.filename_save = "/home/andreas/Physics/nelder_mead/basinhopping_photons_%s"%t.strftime("%Y-%m-%d %H:%M:%S")
        filename_save = self.filename_save
        pumpt = pumptime
        if initial is None:
            if self.constant_on:
                init = np.random.uniform(0, self.scale_factor, self.number_fcp +2)
                init[-1] = 0.3*self.scale_factor
                init[-2] = 0.8*self.scale_factor
            else:
                init = np.random.uniform(-self.max_ampl, self.max_ampl, (self.number_fcp*2))
        else:
            init = initial
            init[-1] *= self.scale_factor
            init[-2] *= self.scale_factor
        self.res = basinhopping(self.calculate_fitness, init, niter_success=15, T=0.02, stepsize=np.pi/4, disp=True, minimizer_kwargs= {'callback':self.plot_stuff, 'method': 'Nelder-Mead'})
        return self.res
    
   
    def plot_stuff(self, fcomps):
        if not self.fig:
            self.fig, ((ax1, ax2), (ax3, ax0)) = plt.subplots(2,2,figsize=(15,10))
        else:
            ax1, ax2, ax3, ax0 = self.fig.axes
            ax1.clear()
            ax2.clear()
            ax3.clear()
            ax0.clear()
            gc.collect()
        pos0 = ax0.get_position()
        pos1 = ax1.get_position()
        pos2 = ax2.get_position()
        pos3 = ax3.get_position()
        pos1n = [(pos2.x0+pos3.x0)/2, pos1.y0,  pos1.width, pos1.height] 
        
        
        ax1.plot(self.tp*1000, self.pulsei, 'b-')
        ax1.plot(self.tp*1000, self.pulseq, 'g-')
        
        szsol = np.real(np.sum(self.solution[:, 2::2], axis=1))
        asol = self.solution[:,0]
        
        ax1.plot(self.tp*1000, np.sqrt(self.pulsei**2+self.pulseq**2), 'k--')
        ax1.set_ylabel("Amplitude (a.u.)")
        ax1.set_xlabel("Time (ns)")        
        ax1.set_ylim([-self.max_t_ampl-50, self.max_t_ampl+50])
        ax1.set_xlim([-20, 20+self.tp[-1]*1000])
        
        idxi = len(self.tp)
        idxpr = idxi +len(self.ti)
        idxdec = idxpr + len(self.tpr)
        
        tlp = self.tp*1000
        tli = self.ti*1000+tlp[-1]
        tlpr = self.tpr*1000+tli[-1]
        tld = self.td*1000+tlpr[-1]
        
        
        ax2.plot(tlp, szsol[:idxi], 'r-')
        ax2.plot(tli, szsol[idxi:idxpr], 'g-')
        ax2.plot(tlpr, szsol[idxpr:idxdec], 'm-')
        ax2.plot(tld, szsol[idxdec:], 'k-')
        ax2.set_ylabel("Inversion")
        ax2.set_xlabel("Time (ns)")
        ax2.set_ylim([-1,1])
        ax3.semilogy(tlp, abs(asol[:idxi])**2, 'b-')
        ax3.semilogy(tli, abs(asol[idxi:idxpr])**2, 'y-')
        ax3.semilogy(tlpr, abs(asol[idxpr:idxdec])**2, 'k-')
        ax3.semilogy(tld, abs(asol[idxdec:])**2, 'c-')
        ax3.set_ylabel("|A|²")
        ax3.set_xlabel("Time (ns)")
        
        ax0.plot(tlpr, abs(asol[idxpr:idxdec])**2, 'r-')
        ax0.plot(tld, abs(asol[idxdec:])**2, 'b-')
        ax0.set_ylabel("|A|²")
        ax0.set_xlabel("Time (ns)")
        #ax1.set_position(pos1n)
        plt.close('all')
        if not self.plot_handle:
            self.plot_handle = display(self.fig, display_id='plot')
        else:
            self.plot_handle.update(self.fig)
        self.counter += 1
        self.disp1.update(Markdown("### Generation %i; Number of Photons: %f; Fitness: %f" %(self.counter, self.maxcav, self.fitness)))
        if self.fitness > self.best_fitness:
            savedict = {'wgrund': self.wgrund, 'time': self.tp, 'timedecay': self.td, 'timeinter': self.ti, 'timeprobe': self.tpr, 'fourier': self.fcomps, 'pulse':np.vstack((self.pulsei, self.pulseq)), 'solution': self.solution, 'fitness': self.fitness, 'nbins':nbins, 'gammaq':gammaq,'gpar': gpar, 'gperp':gperp, 'deltac': deltac, 'delta':delta, 'kappa':kappa,'gs':gs}
            
            pulseforsave = np.zeros((len(self.tp), 3))
            pulseforsave[:,0] = self.tp
            pulseforsave[:,1] = self.pulsei
            pulseforsave[:,2] = self.pulseq
            savedict2 = {'wgrund': self.wgrund, 'puls': pulseforsave}
            if self.fitness >20:
                scipy.io.savemat(self.filename_save, savedict)
                scipy.io.savemat(self.filename_save + '_simple', savedict2)
            self.best_fitness = self.fitness


            
    def calculate_fitness(self, fourier):

        init = np.ones(nbins*g_number*2+1)*(-1)
        init[0] = 0
        init[1::2] = 0
        val_add = 0
        if self.constant_on:
            pt = round(fourier[-1]/self.scale_factor/dt)*dt
            if pt <= self.min_pulse_length:
                pt = self.min_pulse_length
                val_add += 1e6/pt
            ampl = aref*fourier[-2]/self.scale_factor
            self.tp = np.arange(0,pt+dt,dt)
            self.wgrund = np.pi/pt
            self.fcomps = fourier[:-2]
            self.pulsei, self.pulseq = pulse_rwa_gauss_const(self.tp, [self.wgrund, self.fcomps, ampl])
        else:
            self.fcomps = np.reshape(fourier, (self.number_fcp, 2))
            self.pulsei = pulse_rwa_gauss(self.tp, [self.wgrund, self.fcomps[:,0]])
            self.pulseq = pulse_rwa_gauss(self.tp, [self.wgrund, self.fcomps[:,1]])
        solutionpump, solutioninter, solutionprobe, solutiondecay, infodict = solve_mbes_pump_probe(mbes_soc, init, pdf, self.tp, self.ti, self.tpr, self.td, self.ampl_probe, self.pulsei, self.pulseq, self.tp, kappa, deltac, gs, gperp, spins, gpar)

        max_p_ampl = max(np.sqrt(self.pulsei**2+self.pulseq**2))
        max_t = self.tp[-1]
        if self.max_time < max_t:
            val_add += max_t*1e6
        if max_p_ampl > self.max_t_ampl:
            val_add += max_p_ampl*1e6
        self.solution = np.vstack((solutionpump, solutioninter, solutionprobe, solutiondecay))
        self.maxcav = np.sum((abs(solutionprobe[:,0])**2))+np.sum((abs(solutiondecay[:,0])**2))
        self.fitness = self.maxcav
        return -self.maxcav+val_add

def test_func(mbes_soc, init, pdf, x, x1, i, q, tp, kappa, deltac, gs, gperp, spins, gpar):
    return np.ones((len(x), nbins*2+1)), np.ones((len(x1), nbins*2+1)), {}

# %%
gg = BasinHopping()
gg.number_fcp = 1
init = None
for nfcp in range(6):
    res = gg.main(init)
    print("Finished %s step"%nfcp)
    init = [*res.x[:-2],0, res.x[-2], res.x[-1]]
    gg.number_fcp += 1
# Out:
# ### Generation 7816; Number of Photons: 0.006427; Fitness: 0.006427
# basinhopping step 0: f -0.0163573
# basinhopping step 1: f -0.0221223 trial_f -0.0221223 accepted 1  lowest_f -0.0221223
# found new global minimum on step 1 with function value -0.0221223
# basinhopping step 2: f -0.0221223 trial_f 5e+07 accepted 0  lowest_f -0.0221223
# basinhopping step 3: f -0.0221223 trial_f -0.000301119 accepted 0  lowest_f -0.0221223
# basinhopping step 4: f -0.0221223 trial_f -0.0192044 accepted 0  lowest_f -0.0221223
# basinhopping step 5: f -0.0221223 trial_f 5e+07 accepted 0  lowest_f -0.0221223
# basinhopping step 6: f -0.00201846 trial_f -0.00201846 accepted 1  lowest_f -0.0221223
# basinhopping step 7: f -0.0226297 trial_f -0.0226297 accepted 1  lowest_f -0.0226297
# found new global minimum on step 7 with function value -0.0226297
# basinhopping step 8: f -0.0223769 trial_f -0.0223769 accepted 1  lowest_f -0.0226297
# basinhopping step 9: f -0.0200937 trial_f -0.0200937 accepted 1  lowest_f -0.0226297
# basinhopping step 10: f -0.0227158 trial_f -0.0227158 accepted 1  lowest_f -0.0227158
# found new global minimum on step 10 with function value -0.0227158
# basinhopping step 11: f -0.0227158 trial_f -1.72448e-09 accepted 0  lowest_f -0.0227158
# basinhopping step 12: f -4.43971e-05 trial_f -4.43971e-05 accepted 1  lowest_f -0.0227158
# basinhopping step 13: f -0.000282906 trial_f -0.000282906 accepted 1  lowest_f -0.0227158
# basinhopping step 14: f -0.0121405 trial_f -0.0121405 accepted 1  lowest_f -0.0227158
# basinhopping step 15: f -0.0160495 trial_f -0.0160495 accepted 1  lowest_f -0.0227158
# basinhopping step 16: f -0.0173316 trial_f -0.0173316 accepted 1  lowest_f -0.0227158
# basinhopping step 17: f -0.00524065 trial_f -0.00524065 accepted 1  lowest_f -0.0227158
# basinhopping step 18: f -0.0149124 trial_f -0.0149124 accepted 1  lowest_f -0.0227158
# basinhopping step 19: f -0.00789767 trial_f -0.00789767 accepted 1  lowest_f -0.0227158
# basinhopping step 20: f -0.0235707 trial_f -0.0235707 accepted 1  lowest_f -0.0235707
# found new global minimum on step 20 with function value -0.0235707
# basinhopping step 21: f -0.0193882 trial_f -0.0193882 accepted 1  lowest_f -0.0235707
# basinhopping step 22: f -8.86353e-06 trial_f -8.86353e-06 accepted 1  lowest_f -0.0235707
# basinhopping step 23: f -8.86353e-06 trial_f 5e+07 accepted 0  lowest_f -0.0235707
# basinhopping step 24: f -8.86353e-06 trial_f 5e+07 accepted 0  lowest_f -0.0235707
# basinhopping step 25: f -0.0128395 trial_f -0.0128395 accepted 1  lowest_f -0.0235707
# basinhopping step 26: f -0.0182354 trial_f -0.0182354 accepted 1  lowest_f -0.0235707
# basinhopping step 27: f -0.0153227 trial_f -0.0153227 accepted 1  lowest_f -0.0235707
# basinhopping step 28: f -0.0202155 trial_f -0.0202155 accepted 1  lowest_f -0.0235707
# basinhopping step 29: f -0.0226072 trial_f -0.0226072 accepted 1  lowest_f -0.0235707
# basinhopping step 30: f -0.0207705 trial_f -0.0207705 accepted 1  lowest_f -0.0235707
# basinhopping step 31: f -0.0207705 trial_f -0.00137616 accepted 0  lowest_f -0.0235707
# basinhopping step 32: f -0.0225194 trial_f -0.0225194 accepted 1  lowest_f -0.0235707
# basinhopping step 33: f -0.0225194 trial_f -2.32037e-05 accepted 0  lowest_f -0.0235707
# basinhopping step 34: f -0.0206327 trial_f -0.0206327 accepted 1  lowest_f -0.0235707
# basinhopping step 35: f -0.0206327 trial_f 5e+07 accepted 0  lowest_f -0.0235707
# basinhopping step 36: f -0.0206327 trial_f 5e+07 accepted 0  lowest_f -0.0235707
# Finished 0 step
# basinhopping step 0: f -0.016405
# basinhopping step 1: f -0.016405 trial_f -0.0144775 accepted 0  lowest_f -0.016405
# basinhopping step 2: f -0.0224343 trial_f -0.0224343 accepted 1  lowest_f -0.0224343
# found new global minimum on step 2 with function value -0.0224343
# basinhopping step 3: f -0.0151682 trial_f -0.0151682 accepted 1  lowest_f -0.0224343
# basinhopping step 4: f -0.0107809 trial_f -0.0107809 accepted 1  lowest_f -0.0224343
# basinhopping step 5: f -0.0156625 trial_f -0.0156625 accepted 1  lowest_f -0.0224343
# basinhopping step 6: f -0.011926 trial_f -0.011926 accepted 1  lowest_f -0.0224343
# basinhopping step 7: f -0.00837664 trial_f -0.00837664 accepted 1  lowest_f -0.0224343
# basinhopping step 8: f -0.0106888 trial_f -0.0106888 accepted 1  lowest_f -0.0224343
# basinhopping step 9: f -0.129801 trial_f -0.129801 accepted 1  lowest_f -0.129801
# found new global minimum on step 9 with function value -0.129801
# basinhopping step 10: f -0.129801 trial_f -0.032558 accepted 0  lowest_f -0.129801
# basinhopping step 11: f -0.129801 trial_f -0.0186283 accepted 0  lowest_f -0.129801
# basinhopping step 12: f -0.129801 trial_f -0.0119702 accepted 0  lowest_f -0.129801
# basinhopping step 13: f -0.129801 trial_f -0.00848043 accepted 0  lowest_f -0.129801
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -0.129801 trial_f -0.00760768 accepted 0  lowest_f -0.129801
# basinhopping step 15: f -0.129801 trial_f -0.0248964 accepted 0  lowest_f -0.129801
# basinhopping step 16: f -0.129801 trial_f -0.0489708 accepted 0  lowest_f -0.129801
# basinhopping step 17: f -0.129801 trial_f -0.00815359 accepted 0  lowest_f -0.129801
# basinhopping step 18: f -0.129801 trial_f -0.0229509 accepted 0  lowest_f -0.129801
# basinhopping step 19: f -0.129801 trial_f -0.0143834 accepted 0  lowest_f -0.129801
# basinhopping step 20: f -0.129801 trial_f -0.0158032 accepted 0  lowest_f -0.129801
# basinhopping step 21: f -0.129801 trial_f -0.00908107 accepted 0  lowest_f -0.129801
# basinhopping step 22: f -0.129801 trial_f -0.0179278 accepted 0  lowest_f -0.129801
# basinhopping step 23: f -0.129801 trial_f -0.0124894 accepted 0  lowest_f -0.129801
# basinhopping step 24: f -0.129801 trial_f -0.0203398 accepted 0  lowest_f -0.129801
# basinhopping step 25: f -0.129801 trial_f -0.0296793 accepted 0  lowest_f -0.129801
# Finished 1 step
# basinhopping step 0: f -0.0265973
# basinhopping step 1: f -0.0308867 trial_f -0.0308867 accepted 1  lowest_f -0.0308867
# found new global minimum on step 1 with function value -0.0308867
# basinhopping step 2: f -0.0308867 trial_f -0.0228653 accepted 0  lowest_f -0.0308867
# basinhopping step 3: f -0.0308867 trial_f -0.0123346 accepted 0  lowest_f -0.0308867
# basinhopping step 4: f -0.0308867 trial_f -0.0116759 accepted 0  lowest_f -0.0308867
# basinhopping step 5: f -0.0174481 trial_f -0.0174481 accepted 1  lowest_f -0.0308867
# basinhopping step 6: f -0.0151821 trial_f -0.0151821 accepted 1  lowest_f -0.0308867
# basinhopping step 7: f -0.0102392 trial_f -0.0102392 accepted 1  lowest_f -0.0308867
# basinhopping step 8: f -0.0102392 trial_f 5e+07 accepted 0  lowest_f -0.0308867
# basinhopping step 9: f -0.0102392 trial_f 5e+07 accepted 0  lowest_f -0.0308867
# basinhopping step 10: f -0.0102392 trial_f 5e+07 accepted 0  lowest_f -0.0308867
# basinhopping step 11: f -0.0164079 trial_f -0.0164079 accepted 1  lowest_f -0.0308867
# basinhopping step 12: f -0.0210547 trial_f -0.0210547 accepted 1  lowest_f -0.0308867
# basinhopping step 13: f -0.0207032 trial_f -0.0207032 accepted 1  lowest_f -0.0308867
# basinhopping step 14: f -0.0202875 trial_f -0.0202875 accepted 1  lowest_f -0.0308867
# basinhopping step 15: f -0.0202875 trial_f 5e+07 accepted 0  lowest_f -0.0308867
# basinhopping step 16: f -0.0201018 trial_f -0.0201018 accepted 1  lowest_f -0.0308867
# basinhopping step 17: f -0.0201018 trial_f -0.0130585 accepted 0  lowest_f -0.0308867
# Finished 2 step
# basinhopping step 0: f -0.020239
# basinhopping step 1: f -0.020239 trial_f -0.000682572 accepted 0  lowest_f -0.020239
# basinhopping step 2: f -0.0212548 trial_f -0.0212548 accepted 1  lowest_f -0.0212548
# found new global minimum on step 2 with function value -0.0212548
# basinhopping step 3: f -0.0192698 trial_f -0.0192698 accepted 1  lowest_f -0.0212548
# basinhopping step 4: f -0.0192698 trial_f -0.0125474 accepted 0  lowest_f -0.0212548
# basinhopping step 5: f -0.0176443 trial_f -0.0176443 accepted 1  lowest_f -0.0212548
# basinhopping step 6: f -0.0210086 trial_f -0.0210086 accepted 1  lowest_f -0.0212548
# basinhopping step 7: f -0.0210086 trial_f 5e+07 accepted 0  lowest_f -0.0212548
# basinhopping step 8: f -0.0159352 trial_f -0.0159352 accepted 1  lowest_f -0.0212548
# basinhopping step 9: f -0.0215297 trial_f -0.0215297 accepted 1  lowest_f -0.0215297
# found new global minimum on step 9 with function value -0.0215297
# basinhopping step 10: f -0.0272175 trial_f -0.0272175 accepted 1  lowest_f -0.0272175
# found new global minimum on step 10 with function value -0.0272175
# basinhopping step 11: f -0.0272175 trial_f -0.0128109 accepted 0  lowest_f -0.0272175
# basinhopping step 12: f -0.0272175 trial_f -0.0178643 accepted 0  lowest_f -0.0272175
# basinhopping step 13: f -0.0272175 trial_f -0.0178329 accepted 0  lowest_f -0.0272175
# basinhopping step 14: f -0.0272175 trial_f -0.0150287 accepted 0  lowest_f -0.0272175
# basinhopping step 15: f -0.0232413 trial_f -0.0232413 accepted 1  lowest_f -0.0272175
# basinhopping step 16: f -0.0362426 trial_f -0.0362426 accepted 1  lowest_f -0.0362426
# found new global minimum on step 16 with function value -0.0362426
# basinhopping step 17: f -5.88826e-09 trial_f -5.88826e-09 accepted 1  lowest_f -0.0362426
# basinhopping step 18: f -0.0205478 trial_f -0.0205478 accepted 1  lowest_f -0.0362426
# basinhopping step 19: f -0.0231009 trial_f -0.0231009 accepted 1  lowest_f -0.0362426
# basinhopping step 20: f -0.0151344 trial_f -0.0151344 accepted 1  lowest_f -0.0362426
# basinhopping step 21: f -0.158647 trial_f -0.158647 accepted 1  lowest_f -0.158647
# found new global minimum on step 21 with function value -0.158647
# basinhopping step 22: f -0.158647 trial_f -0.0138579 accepted 0  lowest_f -0.158647
# basinhopping step 23: f -0.158647 trial_f -0.0326261 accepted 0  lowest_f -0.158647
# basinhopping step 24: f -0.158647 trial_f -0.00887964 accepted 0  lowest_f -0.158647
# basinhopping step 25: f -0.158647 trial_f -0.0128867 accepted 0  lowest_f -0.158647
# basinhopping step 26: f -0.158647 trial_f -0.0207784 accepted 0  lowest_f -0.158647
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-b992a0151444> in <module>
#       3 init = None
#       4 for nfcp in range(6):
# ----> 5     res = gg.main(init)
#       6     print("Finished %s step"%nfcp)
#       7     init = [*res.x[:-2],0, res.x[-2], res.x[-1]]
#
# <ipython-input-14-5e190fed78c4> in main(self, initial)
#      48             init[-1] *= self.scale_factor
#      49             init[-2] *= self.scale_factor
# ---> 50         self.res = basinhopping(self.calculate_fitness, init, niter_success=15, T=0.02, stepsize=np.pi/4, disp=True, minimizer_kwargs= {'callback':self.plot_stuff, 'method': 'Nelder-Mead'})
#      51         return self.res
#      52
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/_basinhopping.py in basinhopping(func, x0, niter, T, stepsize, minimizer_kwargs, take_step, accept_test, callback, interval, disp, niter_success, seed)
#     684                " successfully"]
#     685     for i in range(niter):
# --> 686         new_global_min = bh.one_cycle()
#     687
#     688         if callable(callback):
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/_basinhopping.py in one_cycle(self)
#     150         new_global_min = False
#     151
# --> 152         accept, minres = self._monte_carlo_step()
#     153
#     154         if accept:
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/_basinhopping.py in _monte_carlo_step(self)
#     102
#     103         # do a local minimization
# --> 104         minres = self.minimizer(x_after_step)
#     105         x_after_quench = minres.x
#     106         energy_after_quench = minres.fun
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/_basinhopping.py in __call__(self, x0)
#     282             return self.minimizer(x0, **self.kwargs)
#     283         else:
# --> 284             return self.minimizer(self.func, x0, **self.kwargs)
#     285
#     286
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     604
#     605     if meth == 'nelder-mead':
# --> 606         return _minimize_neldermead(fun, x0, args, callback, **options)
#     607     elif meth == 'powell':
#     608         return _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     734                     # Perform an inside contraction
#     735                     xcc = (1 - psi) * xbar + psi * sim[-1]
# --> 736                     fxcc = func(xcc)
#     737
#     738                     if fxcc < fsim[-1]:
#
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     425     def function_wrapper(*wrapper_args):
#     426         ncalls[0] += 1
# --> 427         return function(*(wrapper_args + args))
#     428
#     429     return ncalls, function_wrapper
#
# <ipython-input-14-5e190fed78c4> in calculate_fitness(self, fourier)
#     153             self.pulsei = pulse_rwa_gauss(self.tp, [self.wgrund, self.fcomps[:,0]])
#     154             self.pulseq = pulse_rwa_gauss(self.tp, [self.wgrund, self.fcomps[:,1]])
# --> 155         solutionpump, solutioninter, solutionprobe, solutiondecay, infodict = solve_mbes_pump_probe(mbes_soc, init, pdf, self.tp, self.ti, self.tpr, self.td, self.ampl_probe, self.pulsei, self.pulseq, self.tp, kappa, deltac, gs, gperp, spins, gpar)
#     156
#     157         max_p_ampl = max(np.sqrt(self.pulsei**2+self.pulseq**2))
#
# ~/Dropbox/iPython-Notebooks/_do_calculation.ipynb in solve_mbes_pump_probe(mbes_func, init, pdf, tlistpump, tlistinter, tlistprobe, tlistdecay, ampl_probe, *args)
#      91     "        sold = 0\n",
#      92     "        sold_ret = np.empty((len(tlistdecay), len(pdf)*2+1), dtype=complex)\n",
# ---> 93     "        for k in range(reshape_idx):\n",
#      94     "            sold += soldecay[:, (1+2*k*len(pdf)):(1+2*(k+1)*len(pdf))]\n",
#      95     "        solp_ret[:,2::2] = solp[:,1::2]*pdf/reshape_idx\n",
#
# ~/Dropbox/iPython-Notebooks/_helper_functions.ipynb in odeintz(func, z0, t, **kwargs)
#      20    "outputs": [],
#      21    "source": [
# ---> 22     "def tsallis(f, q, width):\n",
#      23     "    delta = (width)/2*np.sqrt(2*q-2)/np.sqrt(2**q-2)/np.sqrt(2)\n",
#      24     "    norm = np.sqrt(q-1)*gamma(1/(q-1))/(np.sqrt(2*np.pi)*delta*gamma((3-q)/(2*(q-1))))\n",
#
# /usr/local/lib/python3.8/dist-packages/scipy/integrate/odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     239     t = copy(t)
#     240     y0 = copy(y0)
# --> 241     output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     242                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     243                              ixpr, mxstep, mxhnil, mxordn, mxords,
#
# ~/Dropbox/iPython-Notebooks/_helper_functions.ipynb in realfunc(x, t, *args)
#      14    ]
#      15   },
# ---> 16   {
#      17    "cell_type": "code",
#      18    "execution_count": 2,
#
# ~/Dropbox/iPython-Notebooks/_mbes.ipynb in mbes_soc(Y, t, ilist, qlist, tlist, kappa, deltac, gs, gperp, spins, gpar)
#      21    ]
#      22   },
# ---> 23   {
#      24    "cell_type": "code",
#      25    "execution_count": 1,
#
# KeyboardInterrupt:

# %%
# %qtconsole
